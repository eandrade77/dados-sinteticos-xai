# %%
import os
import keras
from keras.applications import xception as inc_net
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.imagenet_utils import decode_predictions
from skimage.io import imread
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
print('Notebook run using keras:', keras.__version__)
# Out:
# Using TensorFlow backend.
# Notebook run using keras: 2.2.4

# %%
img_path = 'c:/Users/andradee/\Documents/audiodeep/image_downloader/image_downloader/images/german-shepherd 2020_09_11_total/teste/8.German-Shepherd-Dog-Pictures-2.png'
img = image.load_img(img_path, target_size=(299, 299))

# %%
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.

plt.imshow(img_tensor[0])
plt.show()

# %%
mask_path = 'c:/Users/andradee/\Documents/audiodeep/image_downloader/image_downloader/images/german-shepherd 2020_09_11_total/mask/8.German-Shepherd-Dog-Pictures-2.png'
mask = image.load_img(mask_path, target_size=(299, 299))

# %%
mask_tensor = image.img_to_array(mask)
mask_tensor = np.expand_dims(mask_tensor, axis=0)
mask_tensor /= 255.

plt.imshow(mask_tensor[0])
plt.show()

# %%
mask_tensor.shape
# Out:
# (1, 299, 299, 3)

# %%
def converter(x):

    #x has shape (batch, width, height, channels)
    return (0.21 * x[:,:,:,:1]) + (0.72 * x[:,:,:,1:2]) + (0.07 * x[:,:,:,-1:])

# %%
mask2=converter(mask_tensor)

# %%
mask2.shape
# Out:
# (299, 299)

# %%
mask2 = mask2.reshape([ 299, 299])

# %%
mask2.shape
# Out:
# (299, 299)

# %%
plt.imshow(mask2)
